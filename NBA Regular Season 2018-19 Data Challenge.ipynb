# %% [markdown]
# # Nba Regular Season 2018-19 Data Challenge
#
# Your task will be to take the dataset given, and create an analysis answering the following 10 questions. This project will again test your knowledge of pandas in order to find the answers needed given the data you are presented with.

# %% [markdown]
# # What was the average age of player in the league?

# %%
import pandas as pd
import numpy as np

nbaStats = pd.read_csv('nbastats2018-2019.csv', sep = ',')
nbaStats['Age'].mean()
# 25.900191938579656
# Out:
# 25.900191938579656

# %% [markdown]
# # What player scored the most points?

# %%
nbaStats.sort_values('Points', ascending = False)['Name']
# James Harden
# Out:
# 202             James Harden
# 179              Paul George
# 15     Giannis Antetokounmpo
# 151              Joel Embiid
# 253             LeBron James
#                ...
# 192           Donte Grantham
# 242             Andre Ingram
# 498              Okaro White
# 442             Kobi Simmons
# 14              Ike Anigbogu
# Name: Name, Length: 521, dtype: object

# %% [markdown]
# # What player had the most blocks during the season? Was it a post player (F/C)?

# %%
nbaStats.sort_values('Blocks', ascending = False)
# Myles Turner
# Out:
#                    Name  Height  Weight                  Team  Age    Salary  \
# 476        Myles Turner      83     250        Indiana Pacers   22   3410284
# 123       Anthony Davis      82     253  New Orleans Pelicans   25  25434263
# 419   Mitchell Robinson      85     240       New York Knicks   20   1485440
# 183         Rudy Gobert      85     245             Utah Jazz   26  23241573
# 303         Brook Lopez      84     270       Milwaukee Bucks   30   3382000
# ..                  ...     ...     ...                   ...  ...       ...
# 416     Duncan Robinson      80     210                   NaN   24         -
# 413  Malachi Richardson      78     205    Philadelphia 76ers   23   1569360
# 410          Davon Reed      77     208          Phoenix Suns   23   1378242
# 259        B.J. Johnson      79     200         Atlanta Hawks   23     94742
# 147        Trevon Duval      74     189                   NaN   20         -
#
# ...

# %% [markdown]
# # Based on the regular season, who had the best chance to win a title given their win percentage?

# %% [markdown]
# # What player had the best 3-pt percentage?

# %%
nbaStats.sort_values('FG3%', ascending = False)
# Scott Machado
# Out:
#                  Name  Height  Weight                  Team  Age    Salary  \
# 312     Scott Machado      73     205    Los Angeles Lakers   28     47371
# 439     Jordan Sibert      76     187         Atlanta Hawks   26     47371
# 147      Trevon Duval      74     189                   NaN   20         -
# 352     Eric Moreland      82     238          Phoenix Suns   27    239035
# 95       Troy Caupain      76     210                   NaN   23         -
# ..                ...     ...     ...                   ...  ...       ...
# 468  Tristan Thompson      82     238   Cleveland Cavaliers   27  17469565
# 477         Ekpe Udoh      82     245             Utah Jazz   31   3360000
# 507   Robert Williams      82     240        Boston Celtics   21   1654440
# 519        Ante Zizic      83     254   Cleveland Cavaliers   22   1952760
# 520       Ivica Zubac      85     240  Los Angeles Clippers   21   1544951
#
# ...

# %% [markdown]
# # Who played the most minutes during the season

# %%
nbaStats.sort_values('MP', ascending = False)
# Paul George and Bradley Beal
# Out:
#                   Name  Height  Weight                   Team  Age    Salary  \
# 179        Paul George      81     220  Oklahoma City Thunder   28  30560700
# 37        Bradley Beal      77     207     Washington Wizards   25  25434263
# 202       James Harden      77     220        Houston Rockets   29  30431854
# 496  Russell Westbrook      75     200  Oklahoma City Thunder   30  35654150
# 226       Jrue Holiday      76     205   New Orleans Pelicans   28  25976111
# ..                 ...     ...     ...                    ...  ...       ...
# 14        Ike Anigbogu      82     250         Indiana Pacers   20   1378242
# 498        Okaro White      80     205     Washington Wizards   26    264919
# 442       Kobi Simmons      77     166    Cleveland Cavaliers   21     76236
# 405            Zhou Qi      85     210        Houston Rockets   23    506134
# 192     Donte Grantham      80     215                    NaN   23         -
#
# ...

# %% [markdown]
# # What player given their player effiecency rating was the clutchest during the season?

# %%
nbaStats.sort_values('PER', ascending = False)
# Zhou Qi
# Out:
#                       Name  Height  Weight                Team  Age    Salary  \
# 405                Zhou Qi      85     210     Houston Rockets   23    506134
# 147           Trevon Duval      74     189                 NaN   20         -
# 394         Gary Payton II      75     190  Washington Wizards   26     85458
# 501          Alan Williams      80     265                 NaN   26         -
# 15   Giannis Antetokounmpo      83     242     Milwaukee Bucks   24  24157304
# ..                     ...     ...     ...                 ...  ...       ...
# 498            Okaro White      80     205  Washington Wizards   26    264919
# 14            Ike Anigbogu      82     250      Indiana Pacers   20   1378242
# 242           Andre Ingram      75     190  Los Angeles Lakers   33     76236
# 268         Terrence Jones      81     252     Houston Rockets   27    198580
# 192         Donte Grantham      80     215                 NaN   23         -
#
# ...

# %% [markdown]
# # What team had the youngest roster?

# %%
youngestRoster = nbaStats.groupby('Team').mean()['Age']
print(youngestRoster)
youngestRoster.min()
# Chicago Bulls
# Out:
# Team
# Atlanta Hawks             26.476190
# Boston Celtics            25.600000
# Brooklyn Nets             25.555556
# Charlotte Hornets         26.000000
# Chicago Bulls             24.312500
# Cleveland Cavaliers       26.000000
# Dallas Mavericks          27.866667
# Denver Nuggets            25.266667
# Detroit Pistons           26.266667
# Golden State Warriors     27.866667
# Houston Rockets           27.923077
# Indiana Pacers            25.058824
# Los Angeles Clippers      27.105263
# Los Angeles Lakers        26.625000
# Memphis Grizzlies         25.647059
# Miami Heat                28.181818
# Milwaukee Bucks           26.928571
# Minnesota Timberwolves    26.625000
# New Orleans Pelicans      25.777778
# New York Knicks           24.625000
# Oklahoma City Thunder     25.750000
# Orlando Magic             24.533333
# Philadelphia 76ers        26.352941
# Phoenix Suns              24.761905
# Portland Trail Blazers    24.857143
# Sacramento Kings          24.400000
# ...

# %% [markdown]
# # Who is the highest paid player during the seasion?

# %%
nbaStats.sort_values('Salary', ascending = False)
# Out:
#                     Name  Height  Weight                 Team  Age   Salary  \
# 255         John Jenkins      76     215   Washington Wizards   27    99290
# 188      Devonte' Graham      74     185    Charlotte Hornets   23   988464
# 402        Dwight Powell      83     240     Dallas Mavericks   27  9631250
# 129  Matthew Dellavedova      76     200  Cleveland Cavaliers   28  9607500
# 157           Dante Exum      78     190            Utah Jazz   23  9600000
# ..                   ...     ...     ...                  ...  ...      ...
# 96       Tyler Cavanaugh      81     238                  NaN   24        -
# 92           Alex Caruso      77     186                  NaN   24        -
# 292           Damion Lee      78     210                  NaN   26        -
# 293       Walt Lemon Jr.      75     180                  NaN   26        -
# 175        Billy Garrett      78     213                  NaN   24        -
#
# ...

# %% [markdown]
# # At the end of a game, who WOULDN'T you want on the Free Throw Line?

# %%
nbaStats.sort_values('FT%', ascending = True)
# Terrence Jones
# Out:
#                    Name  Height  Weight                   Team  Age   Salary  \
# 268      Terrence Jones      81     252        Houston Rockets   27   198580
# 221   Haywood Highsmith      79     220                    NaN   22        -
# 356  Donatas Motiejunas      84     222      San Antonio Spurs   28    59820
# 502       C.J. Williams      77     226                    NaN   28        -
# 154         Jacob Evans      78     210  Golden State Warriors   21  1644240
# ..                  ...     ...     ...                    ...  ...      ...
# 410          Davon Reed      77     208           Phoenix Suns   23  1378242
# 439       Jordan Sibert      76     187          Atlanta Hawks   26    47371
# 442        Kobi Simmons      77     166    Cleveland Cavaliers   21    76236
# 498         Okaro White      80     205     Washington Wizards   26   264919
# 514          Nick Young      79     210         Denver Nuggets   33   311070
#
# ...
